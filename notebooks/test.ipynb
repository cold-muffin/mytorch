# %%
from dense_layer import DenseLayer
from activation import ReLU

import numpy as np

# %%
NUM_FEATURES = 3
NUM_SAMPLES = 1
inputs = np.random.rand(NUM_SAMPLES, NUM_FEATURES) * 2 - 1
inputs
# Out:
# array([[-0.23883764,  0.49586391,  0.74874545]])

# %%
layer0 = DenseLayer(2, NUM_FEATURES)
print("Weights:")
print(layer0.weights)
print("\nBiases:")
print(layer0.biases)
# Out:
# Weights:
# [[0.30822319 0.4316984  0.07726399]
#  [0.40911319 0.98075345 0.58638497]]
#
# Biases:
# [[0.72719591 0.42093481]]

# %%
outputs = layer0.forward(inputs)
outputs
# Out:
# array([[0.92549532, 1.2485965 ]])

# %%
f = ReLU()
f(outputs)
# Out:
# array([[0.92549532, 1.2485965 ]])

# %%
arr = np.array([[0, 1, 2], [2, 1, 0]])
print(arr)
exp = np.exp(arr - np.max(arr))
print(exp)
exp / np.sum(exp, axis=1, keepdims=True)
# Out:
# [[0 1 2]
#  [2 1 0]]
# [[0.13533528 0.36787944 1.        ]
#  [1.         0.36787944 0.13533528]]
# array([[0.09003057, 0.24472847, 0.66524096],
#        [0.66524096, 0.24472847, 0.09003057]])

# %%
np.argmax(np.array([0, 0, 1, 0, 0]))
# Out:
# np.int64(2)

# %%
inp = np.array([[.7, .1, .2],[.5, .2, .3],[.2, .6, .2]])
truth = np.array([0, 2, 1])
print(inp[range(len(truth)), truth])
# Out:
# [0.7 0.3 0.6]

# %%
inp = np.array([[.7, .1, .2],[.5, .2, .3],[.2, .6, .2]])
truth = np.array([[1, 0, 0],[0, 0, 1],[0, 1, 0]])
print(inp[range(len(truth)), np.argmax(truth, axis=1)])
# Out:
# [0.7 0.3 0.6]

# %%
from loss import CrossEntropy
f = CrossEntropy()

# %%
loss = f(
  np.array([[1, 0, 0],[0, 0, 1],[0, 1, 0]]), 
  np.array([[.7, .1, .2],[.5, .2, 0],[.2, .6, .2]])
)
print(loss)
np.average(loss)
# Out:
# [ 0.35667494 16.11809565  0.51082562]
# np.float64(5.661865406221015)
